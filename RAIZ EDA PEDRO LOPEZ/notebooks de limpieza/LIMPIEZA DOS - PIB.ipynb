# %% [markdown]
# ## DATASET 2 - GASTO POR PIB

# %%
import pandas as pd 

import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#  PARA VER TODAS LAS LÍNEAS DEL DF 
pd.set_option('display.max_rows', None)  # Mostrar todas las filas

# Y PARA RESETEARLO: pd.reset_option('display.max_rows')

# %%
# dataset 2 : GASTO DEFENSA SEGÚN PIB
gasto_pib = pd.read_csv(r'C:\Users\pedlo\Desktop\MATERIALES BOOTCAMP DATA\EDAAAAAAA\PORCENTAJE PIB -GASTO DEFENSA.csv', skiprows=5)
gasto_pib.head(10)
# Out:
#               Country                      Notes   1960   1961   1962   1963  \
# 0                 NaN                        NaN    NaN    NaN    NaN    NaN
# 1              Africa                        NaN    NaN    NaN    NaN    NaN
# 2        North Africa                        NaN    NaN    NaN    NaN    NaN
# 3             Algeria  #gid=1375736796&range=A15  1,61%  1,92%    ...  2,51%
# 4               Libya  #gid=1375736796&range=A27  1,59%  1,86%  3,10%  2,41%
# 5             Morocco  #gid=1375736796&range=A28  2,32%  2,70%  2,57%  3,20%
# 6             Tunisia                        NaN  2,00%  2,22%  1,73%  1,51%
# 7  sub-Saharan Africa                        NaN    NaN    NaN    NaN    NaN
# 8              Angola  #gid=1375736796&range=A12    ...    ...    ...    ...
# 9               Benin                          §  0,87%  1,40%  1,75%  1,74%
#
#     1964   1965   1966   1967  ...   2015   2016   2017   2018   2019   2020  \
# ...

# %%
##   eliminamos columnas desde Notes hasta 1987

cols = gasto_pib.columns
inicio = cols.get_loc('Notes')
fin = cols.get_loc('1987') 

columnas_a_eliminar = cols[inicio:fin+1]


gasto_pib = gasto_pib.drop(columns=columnas_a_eliminar)

# %%
gasto_pib
# Out:
#                                Country    1988    1989    1990     1991  \
# 0                                  NaN     NaN     NaN     NaN      NaN
# 1                               Africa     NaN     NaN     NaN      NaN
# 2                         North Africa     NaN     NaN     NaN      NaN
# 3                              Algeria   1,75%   1,54%   1,46%    1,21%
# 4                                Libya     ...     ...     ...      ...
# 5                              Morocco   4,13%   4,39%   4,15%    4,14%
# 6                              Tunisia   2,10%   2,11%   1,84%    1,83%
# 7                   sub-Saharan Africa     NaN     NaN     NaN      NaN
# 8                               Angola  21,98%  19,43%  17,46%    7,10%
# 9                                Benin   1,56%   1,31%   1,23%      ...
# 10                            Botswana   4,90%   3,57%   4,45%    4,60%
# 11                        Burkina Faso   2,31%   2,74%   2,70%    2,17%
# ...

# %%
#ponemos países como índice 

gasto_pib =gasto_pib.set_index('Country')

# %%
pd.set_option('display.max_rows', None)  # Mostrar todas las filas

print(gasto_pib.index)
# Out:
# Index([                   nan,               'Africa',         'North Africa',
#                     'Algeria',                'Libya',              'Morocco',
#                     'Tunisia',   'sub-Saharan Africa',               'Angola',
#                       'Benin',
#        ...
#                      'Kuwait',              'Lebanon',                 'Oman',
#                       'Qatar',         'Saudi Arabia',                'Syria',
#                     'Türkiye', 'United Arab Emirates',         'Yemen, North',
#                       'Yemen'],
#       dtype='object', name='Country', length=193)

# %%
print(gasto_pib.index.tolist())
# Out:
# [nan, 'Africa', 'North Africa', 'Algeria', 'Libya', 'Morocco', 'Tunisia', 'sub-Saharan Africa', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon', 'Cape Verde', 'Central African Republic', 'Chad', 'Congo, DR', 'Congo, Republic', "Cote d'Ivoire", 'Djibouti', 'Equatorial Guinea', 'Eritrea', 'Ethiopia', 'Gabon', 'Gambia, The', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Eswatini', 'Tanzania', 'Togo', 'Uganda', 'Zambia', 'Zimbabwe', 'Americas', 'Central America and the Caribbean', 'Belize', 'Costa Rica', 'Cuba', 'Dominican Republic', 'El Salvador', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Trinidad and Tobago', 'North America', 'Canada', 'United States of America', 'South America', 'Argentina', 'Bolivia', '
# ...

# %%
gasto_pib = gasto_pib.drop(['Africa','North Africa', 'sub-Saharan Africa', 'Americas', 'Central America and the Caribbean', 'North America', 'South America', 'Asia & Oceania', 'Oceania', 'South Asia', 'East Asia','South East Asia', 'Central Asia', 'Europe', 'Central Europe', 'Eastern Europe', 'Western Europe', 'Middle East'])

# %%
gasto_pib = gasto_pib.drop(gasto_pib.index[0])

# %%
#vemos si hay nulos 

if gasto_pib.isna().values.any():
    print('cuidado, todavía hay valores NaN')
else: 
    print('adelante, no hay NaN')
# Out:
# adelante, no hay NaN

# %%
gasto_pib.replace(['...', 'xxx'], np.nan, inplace=True)

# %%
gasto_pib['na_por_fila'] = gasto_pib.isna().sum(axis=1)

# %%
gasto_pib['na_por_fila']
# Out:
# Country
# Algeria                        0
# Libya                         20
# Morocco                        0
# Tunisia                        0
# Angola                         0
# Benin                         12
# Botswana                       0
# Burkina Faso                   0
# Burundi                        3
# Cameroon                       0
# Cape Verde                     3
# Central African Republic       9
# Chad                           2
# Congo, DR                      9
# Congo, Republic               15
# Cote d'Ivoire                  6
# Djibouti                      22
# Equatorial Guinea             21
# Eritrea                       26
# Ethiopia                       0
# Gabon                         15
# Gambia, The                    4
# Ghana                          0
# Guinea                        12
# Guinea-Bissau                 11
# Kenya                          0
# Lesotho                        0
# Liberia                       11
# ...

# %%
gasto_pib = gasto_pib[gasto_pib.isna().sum(axis=1) <= 10]

# %%
gasto_pib = gasto_pib.replace('%', '', regex=True)  # Quitar el %
gasto_pib = gasto_pib.replace(',', '.', regex=True)  # Cambiar coma por punto
gasto_pib = gasto_pib.apply(pd.to_numeric, errors='coerce')  # Convertir a float, poniendo NaN donde no se pueda

# %%
gasto_pib = gasto_pib.T.fillna(gasto_pib.mean(axis=1)).T

# %%
gasto_pib = gasto_pib.round(2)

# %%
gasto_pib
# Out:
#                            1988   1989   1990    1991   1992   1993   1994  \
# Country
# Algeria                    1.75   1.54   1.46    1.21   2.14   2.51   3.15
# Morocco                    4.13   4.39   4.15    4.14   4.30   4.66   4.49
# Tunisia                    2.10   2.11   1.84    1.83   1.71   1.73   1.74
# Angola                    21.98  19.43  17.46    7.10   5.68  17.52   5.71
# Botswana                   4.90   3.57   4.45    4.60   4.48   4.93   4.01
# Burkina Faso               2.31   2.74   2.70    2.17   2.05   1.86   1.42
# Burundi                    3.15   3.35   3.45    3.79   3.60   3.72   3.92
# Cameroon                   1.28   1.33   1.47    1.51   1.53   1.33   1.31
# Cape Verde                 1.91   0.75   0.75    0.75   0.99   0.76   0.84
# Central African Republic   1.91   1.91   1.91    1.57   1.64   1.50   1.26
# Chad                       3.56   2.73   1.38    2.04   1.37   1.75   1.22
# ...

# %%
gasto_pib = gasto_pib.T.fillna(gasto_pib.mean(axis=1)).T

# %%
print(gasto_pib.isna().sum().sum())
# Out:
# 0

# %%
gasto_pib = gasto_pib.drop('na_por_fila', axis=1)

# %%
pib = gasto_pib

# %%
pib.to_csv('gasto-PIB.csv')
