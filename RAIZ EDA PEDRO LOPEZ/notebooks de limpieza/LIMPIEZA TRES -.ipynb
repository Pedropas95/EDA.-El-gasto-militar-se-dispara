# %%
import pandas as pd 

import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# dataset 3 : GASTO POR REGIONES 

gasto_regiones = pd.read_csv(r'C:\Users\pedlo\Desktop\MATERIALES BOOTCAMP DATA\EDAAAAAAA\REGIONES - GASTO DEFENSA.csv',skiprows=13)
gasto_regiones.head()
# Out:
#                Region    1988    1989    1990   1991    1992    1993    1994  \
# 0               World  1749,5  1728,7  1660,7    ...  1388,1  1325,2  1291,6
# 1              Africa    20,9    21,2    21,1   18,3    16,8    19,3    26,1
# 2        North Africa     3,4     3,6     3,6    3,7     4,2     4,4     4,8
# 3  sub-Saharan Africa    17,4    17,6    17,5   14,6    12,6    14,9    21,3
# 4            Americas   862,5   853,5   815,1  721,2   755,5   722,2   690,6
#
#      1995    1996  ...    2018    2019    2020    2021    2022    2023  \
# 0  1220,7  1186,1  ...  2038,9  2124,5  2200,4  2222,6  2294,5  2447,4
# 1    15,9    15,1  ...    40,6    41,1    42,3    44,4    42,5    50,2
# 2     4,6     4,9  ...    18,3    19,2    19,9    19,0    18,3    26,2
# 3    11,3    10,2  ...    22,4    21,9    22,5    25,5    24,2    23,9
# 4   652,9   617,3  ...   919,6   966,4  1010,6   999,1   987,1  1009,6
#
#      2024 2024 (current prices) Unnamed: 39           Omitted countries
# ...

# %%
gasto_regiones.set_index('Region',inplace=True)

# %%
gasto_regiones.drop('Unnamed: 39', axis=1, inplace=True)

# %%
gasto_regiones.drop('Omitted countries', axis=1, inplace=True)

# %%
gasto_regiones
# Out:
#                                      1988    1989    1990   1991    1992  \
# Region
# World                              1749,5  1728,7  1660,7    ...  1388,1
# Africa                               20,9    21,2    21,1   18,3    16,8
# North Africa                          3,4     3,6     3,6    3,7     4,2
# sub-Saharan Africa                   17,4    17,6    17,5   14,6    12,6
# Americas                            862,5   853,5   815,1  721,2   755,5
# Central America and the Caribbean     5,2     5,3     4,9    4,7     5,2
# North America                       817,8   810,9   778,0  688,1   723,9
# South America                        39,6    37,3    32,2   28,4    26,4
# Asia & Oceania                      133,2   140,2   146,7  149,2   156,1
# Oceania                              15,7    15,6    15,8   15,9    16,2
# South Asia                           25,7    26,8    26,8   25,9    25,5
# East Asia                            76,3    80,9    85,5   88,6    95,2
# ...

# %%
gasto_regiones = gasto_regiones.replace(',', '.', regex=True)

# %%
regiones = gasto_regiones

# %%
regiones.to_csv('gasto_regiones.csv')
