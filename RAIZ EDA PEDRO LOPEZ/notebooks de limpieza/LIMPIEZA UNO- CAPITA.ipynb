# %%
import pandas as pd 

import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## DATASET 1 - GASTO PER CÁPITA

# %%
# dataset 1: GASTO EN DEFENSA DE CADA PAÍS PER CÁPITA
import pandas as pd
gasto_capita = pd.read_csv(r'C:\Users\pedlo\Desktop\MATERIALES BOOTCAMP DATA\EDAAAAAAA\GASTO DEFENSA - PER CAPITA.csv',skiprows=6)
gasto_capita.head()
# Out:
#         Country                      Notes  1988  1989  1990  1991  1992  \
# 0        Africa                        NaN   NaN   NaN   NaN   NaN   NaN
# 1  North Africa                        NaN   NaN   NaN   NaN   NaN   NaN
# 2       Algeria  #gid=1375736796&range=A15  43,3  35,0  36,1  22,0  40,1
# 3         Libya  #gid=1375736796&range=A27   ...   ...   ...   ...   ...
# 4       Morocco  #gid=1375736796&range=A28  39,4  41,8  44,3  46,7  49,1
#
#    1993  1994  1995  ...   2015   2016   2017   2018   2019   2020   2021  \
# 0   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2  47,4  48,4  43,8  ...  262,7  252,7  244,1  227,6  240,2  222,2  205,2
# 3   ...   ...   ...  ...    ...    ...    ...    ...    ...    ...    ...
# 4  49,2  52,9  54,9  ...   95,0   95,6   98,2  103,7  103,3  132,7  146,3
#
#     2022   2023   2024
# 0    NaN    NaN    NaN
# 1    NaN    NaN    NaN
# ...

# %%
gasto_capita
# Out:
#                                Country                       Notes    1988  \
# 0                               Africa                         NaN     NaN
# 1                         North Africa                         NaN     NaN
# 2                              Algeria   #gid=1375736796&range=A15    43,3
# 3                                Libya   #gid=1375736796&range=A27     ...
# 4                              Morocco   #gid=1375736796&range=A28    39,4
# 5                              Tunisia                         NaN    29,5
# 6                   sub-Saharan Africa                         NaN     NaN
# 7                               Angola   #gid=1375736796&range=A12   137,6
# 8                                Benin                           §     7,6
# 9                             Botswana                         NaN    77,0
# 10                        Burkina Faso                           †     6,7
# ...

# %%
# quitamos la columna 'Notes' 

gasto_capita = gasto_capita.drop('Notes', axis=1)

# %%
gasto_capita
# Out:
#                                Country    1988    1989    1990     1991  \
# 0                               Africa     NaN     NaN     NaN      NaN
# 1                         North Africa     NaN     NaN     NaN      NaN
# 2                              Algeria    43,3    35,0    36,1     22,0
# 3                                Libya     ...     ...     ...      ...
# 4                              Morocco    39,4    41,8    44,3     46,7
# 5                              Tunisia    29,5    29,0    30,1     31,0
# 6                   sub-Saharan Africa     NaN     NaN     NaN      NaN
# 7                               Angola   137,6   176,4   153,2     87,2
# 8                                Benin     7,6     5,7     6,3      ...
# 9                             Botswana    77,0    82,0   121,3    130,2
# 10                        Burkina Faso     6,7     7,6     9,3      7,5
# 11                             Burundi     6,4     7,0     7,2      7,6
# ...

# %%
#eliminamos las filas de los continentes y creamos una columna 'continente'. 

gasto_capita = gasto_capita.dropna()

# %%
gasto_capita = gasto_capita.set_index('Country')

# %%
gasto_capita
# Out:
#                               1988    1989    1990     1991    1992    1993  \
# Country
# Algeria                       43,3    35,0    36,1     22,0    40,1    47,4
# Libya                          ...     ...     ...      ...     ...     ...
# Morocco                       39,4    41,8    44,3     46,7    49,1    49,2
# Tunisia                       29,5    29,0    30,1     31,0    33,7    31,5
# Angola                       137,6   176,4   153,2     87,2    65,0   140,6
# Benin                          7,6     5,7     6,3      ...     ...     ...
# Botswana                      77,0    82,0   121,3    130,2   130,9   132,6
# Burkina Faso                   6,7     7,6     9,3      7,5     7,5     6,2
# Burundi                        6,4     7,0     7,2      7,6     6,8     6,1
# Cameroon                      14,7    13,5    16,2     15,5    15,5    13,8
# Cape Verde                    14,1     ...     ...      ...     9,1     6,9
# ...

# %%
print(gasto_capita.index.tolist())
# Out:
# ['Algeria', 'Libya', 'Morocco', 'Tunisia', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon', 'Cape Verde', 'Central African Republic', 'Chad', 'Congo, DR', 'Congo, Republic', "Cote d'Ivoire", 'Djibouti', 'Equatorial Guinea', 'Eritrea', 'Ethiopia', 'Gabon', 'Gambia, The', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Eswatini', 'Tanzania', 'Togo', 'Uganda', 'Zambia', 'Zimbabwe', 'Belize', 'Costa Rica', 'Cuba', 'Dominican Republic', 'El Salvador', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Trinidad and Tobago', 'Canada', 'United States of America', 'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay', 'Peru', 'Uruguay', 'Venezuela', 'Australia', 'Fiji', 'New Zealand', 'Papu
# ...

# %%
#nueva fila 'Continent
gasto_capita['Continent'] = ''

# %%
#empezamos a asignar a los países sus continentes
gasto_capita.loc['Algeria':'Zimbabwe', 'Continent'] = 'Africa'

# %%
print(gasto_capita['Continent'])
# Out:
# Country
# Algeria                       Africa
# Libya                         Africa
# Morocco                       Africa
# Tunisia                       Africa
# Angola                        Africa
# Benin                         Africa
# Botswana                      Africa
# Burkina Faso                  Africa
# Burundi                       Africa
# Cameroon                      Africa
# Cape Verde                    Africa
# Central African Republic      Africa
# Chad                          Africa
# Congo, DR                     Africa
# Congo, Republic               Africa
# Cote d'Ivoire                 Africa
# Djibouti                      Africa
# Equatorial Guinea             Africa
# Eritrea                       Africa
# Ethiopia                      Africa
# Gabon                         Africa
# Gambia, The                   Africa
# Ghana                         Africa
# Guinea                        Africa
# Guinea-Bissau                 Africa
# ...

# %%
gasto_capita.loc['Belize':'United States of America','Continent'] = 'Central_North_America'

gasto_capita.loc['Argentina':'Venezuela','Continent'] = 'South_America'
gasto_capita.loc['Australia':'Papua New Guinea','Continent'] = 'Oceania'
gasto_capita.loc['Afghanistan': 'Uzbekistan','Continent'] = 'Asia'
gasto_capita.loc['Albania':'United Kingdom','Continent'] = 'Europe'
gasto_capita.loc['Bahrain':'Yemen','Continent'] = 'Middle_East'

# %%
print(gasto_capita['Continent'])
# Out:
# Country
# Algeria                                      Africa
# Libya                                        Africa
# Morocco                                      Africa
# Tunisia                                      Africa
# Angola                                       Africa
# Benin                                        Africa
# Botswana                                     Africa
# Burkina Faso                                 Africa
# Burundi                                      Africa
# Cameroon                                     Africa
# Cape Verde                                   Africa
# Central African Republic                     Africa
# Chad                                         Africa
# Congo, DR                                    Africa
# Congo, Republic                              Africa
# Cote d'Ivoire                                Africa
# Djibouti                                     Africa
# Equatorial Guinea                            Africa
# ...

# %%
gasto_capita
# Out:
#                               1988    1989    1990     1991    1992    1993  \
# Country
# Algeria                       43,3    35,0    36,1     22,0    40,1    47,4
# Libya                          ...     ...     ...      ...     ...     ...
# Morocco                       39,4    41,8    44,3     46,7    49,1    49,2
# Tunisia                       29,5    29,0    30,1     31,0    33,7    31,5
# Angola                       137,6   176,4   153,2     87,2    65,0   140,6
# Benin                          7,6     5,7     6,3      ...     ...     ...
# Botswana                      77,0    82,0   121,3    130,2   130,9   132,6
# Burkina Faso                   6,7     7,6     9,3      7,5     7,5     6,2
# Burundi                        6,4     7,0     7,2      7,6     6,8     6,1
# Cameroon                      14,7    13,5    16,2     15,5    15,5    13,8
# Cape Verde                    14,1     ...     ...      ...     9,1     6,9
# ...

# %%
# eliminamos a la URSS (porque no hay datos) y a la Unión Europea, porque representa a un grupo de países de los que ya tenemos datos por separado

gasto_capita = gasto_capita.drop(['USSR','European Union'])

# %%
#vemos si hay nulos 

if gasto_capita.isna().values.any():
    print('cuidado, todavía hay valores NaN')
else: 
    print('adelante, no hay NaN')
# Out:
# adelante, no hay NaN

# %%
#Repasamos para ver si nos hemos saltado algo

gasto_capita.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 172 entries, Algeria to Yemen
# Data columns (total 38 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   1988       172 non-null    object
#  1   1989       172 non-null    object
#  2   1990       172 non-null    object
#  3   1991       172 non-null    object
#  4   1992       172 non-null    object
#  5   1993       172 non-null    object
#  6   1994       172 non-null    object
#  7   1995       172 non-null    object
#  8   1996       172 non-null    object
#  9   1997       172 non-null    object
#  10  1998       172 non-null    object
#  11  1999       172 non-null    object
#  12  2000       172 non-null    object
#  13  2001       172 non-null    object
#  14  2002       172 non-null    object
#  15  2003       172 non-null    object
#  16  2004       172 non-null    object
#  17  2005       172 non-null    object
#  18  2006       172 non-null    object
# ...

# %%
gasto_capita
# Out:
#                               1988    1989    1990     1991    1992    1993  \
# Country
# Algeria                       43,3    35,0    36,1     22,0    40,1    47,4
# Libya                          ...     ...     ...      ...     ...     ...
# Morocco                       39,4    41,8    44,3     46,7    49,1    49,2
# Tunisia                       29,5    29,0    30,1     31,0    33,7    31,5
# Angola                       137,6   176,4   153,2     87,2    65,0   140,6
# Benin                          7,6     5,7     6,3      ...     ...     ...
# Botswana                      77,0    82,0   121,3    130,2   130,9   132,6
# Burkina Faso                   6,7     7,6     9,3      7,5     7,5     6,2
# Burundi                        6,4     7,0     7,2      7,6     6,8     6,1
# Cameroon                      14,7    13,5    16,2     15,5    15,5    13,8
# Cape Verde                    14,1     ...     ...      ...     9,1     6,9
# ...

# %%
gasto_capita.describe()
# Out:
#        1988 1989 1990 1991 1992 1993 1994 1995 1996 1997  ... 2016 2017 2018  \
# count   172  172  172  172  172  172  172  172  172  172  ...  172  172  172
# unique  108  110  117  114  123  127  129  132  130  134  ...  149  150  151
# top     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# freq     58   58   52   51   44   30   27   29   28   26  ...   15   15   13
#
#        2019 2020 2021 2022 2023 2024 Continent
# count   172  172  172  172  172  172       172
# unique  150  143  151  147  151  146         7
# top     ...  ...  ...  ...  ...  ...    Africa
# freq     17   17   16   17   18   21        51
#
# [4 rows x 38 columns]

# %%
gasto_capita.columns
# Out:
# Index(['1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023',
#        '2024', 'Continent'],
#       dtype='object')

# %%
gasto_capita.index
# Out:
# Index(['Algeria', 'Libya', 'Morocco', 'Tunisia', 'Angola', 'Benin', 'Botswana',
#        'Burkina Faso', 'Burundi', 'Cameroon',
#        ...
#        'Kuwait', 'Lebanon', 'Oman', 'Qatar', 'Saudi Arabia', 'Syria',
#        'Türkiye', 'United Arab Emirates', 'Yemen, North', 'Yemen'],
#       dtype='object', name='Country', length=172)

# %%
gasto_capita.iloc[1]
# Out:
# 1988            ...
# 1989            ...
# 1990            ...
# 1991            ...
# 1992            ...
# 1993            ...
# 1994            ...
# 1995            ...
# 1996            ...
# 1997          249,1
# 1998          282,9
# 1999          222,7
# 2000          206,5
# 2001          153,1
# 2002           83,0
# 2003           97,3
# 2004          120,7
# 2005          119,2
# 2006          103,8
# 2007          105,8
# 2008          178,3
# 2009            ...
# 2010            ...
# 2011            ...
# 2012          488,0
# 2013          635,8
# 2014          589,3
# 2015            ...
# 2016            ...
# 2017            ...
# 2018            ...
# 2019            ...
# 2020            ...
# 2021            ...
# 2022          169,2
# 2023          216,5
# 2024            ...
# Continent    Africa
# Name: Libya, dtype: object

# %%
gasto_capita.replace('...', pd.NA, inplace=True)

# %%
gasto_capita.replace('xxx', pd.NA, inplace=True)

# %%
gasto_capita
# Out:
#                               1988    1989    1990     1991    1992    1993  \
# Country
# Algeria                       43,3    35,0    36,1     22,0    40,1    47,4
# Libya                         <NA>    <NA>    <NA>     <NA>    <NA>    <NA>
# Morocco                       39,4    41,8    44,3     46,7    49,1    49,2
# Tunisia                       29,5    29,0    30,1     31,0    33,7    31,5
# Angola                       137,6   176,4   153,2     87,2    65,0   140,6
# Benin                          7,6     5,7     6,3     <NA>    <NA>    <NA>
# Botswana                      77,0    82,0   121,3    130,2   130,9   132,6
# Burkina Faso                   6,7     7,6     9,3      7,5     7,5     6,2
# Burundi                        6,4     7,0     7,2      7,6     6,8     6,1
# Cameroon                      14,7    13,5    16,2     15,5    15,5    13,8
# Cape Verde                    14,1    <NA>    <NA>     <NA>     9,1     6,9
# ...

# %%
gasto_capita[gasto_capita.isna().any(axis=1)]
# Out:
#                               1988    1989    1990    1991   1992   1993  \
# Country
# Libya                         <NA>    <NA>    <NA>    <NA>   <NA>   <NA>
# Benin                          7,6     5,7     6,3    <NA>   <NA>   <NA>
# Burundi                        6,4     7,0     7,2     7,6    6,8    6,1
# Cape Verde                    14,1    <NA>    <NA>    <NA>    9,1    6,9
# Central African Republic      <NA>    <NA>    <NA>     7,4    7,7    6,2
# Chad                          14,1     9,9     5,8    <NA>    5,6    6,0
# Congo, DR                      6,4     1,9     1,3     1,2    2,2   11,7
# Congo, Republic               <NA>    <NA>    <NA>    <NA>   50,6   42,9
# Cote d'Ivoire                 11,6    11,3    12,1    11,6   12,1   11,0
# Djibouti                      66,2    62,2    56,9    51,9   51,7   51,6
# Equatorial Guinea             <NA>    <NA>    <NA>    <NA>   <NA>   <NA>
# Eritrea                       <NA>    <NA>    <NA>    <NA>   <NA>   59,4
# ...

# %%
gasto_capita['na_por_fila'] = gasto_capita.isna().sum(axis=1)
gasto_capita['na_por_fila']
# Out:
# Country
# Algeria                        0
# Libya                         20
# Morocco                        0
# Tunisia                        0
# Angola                         0
# Benin                         12
# Botswana                       0
# Burkina Faso                   0
# Burundi                        3
# Cameroon                       0
# Cape Verde                     3
# Central African Republic       9
# Chad                           2
# Congo, DR                      4
# Congo, Republic               15
# Cote d'Ivoire                  6
# Djibouti                      16
# Equatorial Guinea             21
# Eritrea                       26
# Ethiopia                       0
# Gabon                         15
# Gambia, The                    4
# Ghana                          0
# Guinea                        12
# Guinea-Bissau                 11
# Kenya                          0
# Lesotho                        0
# Liberia                       11
# ...

# %%
pd.set_option('display.max_rows', None)  # muestra todas las filas

print(gasto_capita['na_por_fila'])
# Out:
# Country
# Algeria                        0
# Libya                         20
# Morocco                        0
# Tunisia                        0
# Angola                         0
# Benin                         12
# Botswana                       0
# Burkina Faso                   0
# Burundi                        3
# Cameroon                       0
# Cape Verde                     3
# Central African Republic       9
# Chad                           2
# Congo, DR                      4
# Congo, Republic               15
# Cote d'Ivoire                  6
# Djibouti                      16
# Equatorial Guinea             21
# Eritrea                       26
# Ethiopia                       0
# Gabon                         15
# Gambia, The                    4
# Ghana                          0
# Guinea                        12
# Guinea-Bissau                 11
# Kenya                          0
# Lesotho                        0
# Liberia                       11
# ...

# %%
print(gasto_capita[gasto_capita.isna().any(axis=1)]['na_por_fila'])
# Out:
# Country
# Libya                         20
# Benin                         12
# Burundi                        3
# Cape Verde                     3
# Central African Republic       9
# Chad                           2
# Congo, DR                      4
# Congo, Republic               15
# Cote d'Ivoire                  6
# Djibouti                      16
# Equatorial Guinea             21
# Eritrea                       26
# Gabon                         15
# Gambia, The                    4
# Guinea                        12
# Guinea-Bissau                 11
# Liberia                       11
# Mali                           2
# Mauritania                     4
# Namibia                        2
# Niger                          9
# Somalia                       23
# South Sudan                   18
# Sudan                          9
# Togo                           9
# Zambia                         5
# Zimbabwe                       4
# Belize                         3
# ...

# %%
# como vemos, tengo que eliminar muchos países de la muestra. Libia, Benin, Camerún... Eliminamos los que tienen más de 6 Nan (sobre todo porque así nos quedamos con China y Rusia) 

gasto_capita = gasto_capita[gasto_capita.isna().sum(axis=1) <= 5]

# %%
gasto_capita[gasto_capita['Continent'] == ''].index
# Out:
# Index([], dtype='object', name='Country')

# %%
print(gasto_capita[gasto_capita.isna().any(axis=1)]['na_por_fila'])
# Out:
# Country
# Burundi        3
# Cape Verde     3
# Chad           2
# Congo, DR      4
# Gambia, The    4
# Mali           2
# Mauritania     4
# Namibia        2
# Zambia         5
# Zimbabwe       4
# Belize         3
# Nicaragua      2
# Guyana         3
# Venezuela      1
# China          1
# Mongolia       3
# Cambodia       2
# Albania        4
# Bulgaria       1
# Croatia        4
# Czechia        5
# Estonia        5
# Latvia         5
# Lithuania      5
# Slovakia       5
# Slovenia       4
# Azerbaijan     4
# Russia         5
# Ukraine        5
# Lebanon        1
# Name: na_por_fila, dtype: int64

# %%
print("Número de NaN por fila:")
print(gasto_capita.isna().sum(axis=1))
# Out:
# Número de NaN por fila:
# Country
# Algeria                     0
# Morocco                     0
# Tunisia                     0
# Angola                      0
# Botswana                    0
# Burkina Faso                0
# Burundi                     3
# Cameroon                    0
# Cape Verde                  3
# Chad                        2
# Congo, DR                   4
# Ethiopia                    0
# Gambia, The                 4
# Ghana                       0
# Kenya                       0
# Lesotho                     0
# Madagascar                  0
# Malawi                      0
# Mali                        2
# Mauritania                  4
# Mauritius                   0
# Mozambique                  0
# Namibia                     2
# Nigeria                     0
# Rwanda                      0
# Senegal                     0
# Seychelles                  0
# Sierra Leone                0
# South Africa                0
# Eswatini                    0
# ...

# %%
def fill_with_row_mean(row):
    # Convierte a float para evitar problemas con pd.NA o tipos pandas especiales
    row_float = row.astype(float)
    return row_float.fillna(row_float.mean())

numericas_filled = numericas.apply(fill_with_row_mean, axis=1)
gasto_capita.loc[:, numericas.columns] = numericas_filled
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 6
#       3     row_float = row.astype(float)
#       4     return row_float.fillna(row_float.mean())
# ----> 6 numericas_filled = numericas.apply(fill_with_row_mean, axis=1)
#       7 gasto_capita.loc[:, numericas.columns] = numericas_filled
#
# NameError: name 'numericas' is not defined

# %%
import pandas as pd
import numpy as np

# Supongamos que 'gasto_capita' ya está cargado

# 1. Convertir pd.NA a np.nan para evitar problemas
gasto_capita = gasto_capita.replace({pd.NA: np.nan})

# 2. Separar las columnas numéricas
numericas = gasto_capita.select_dtypes(include=[np.number])

# 3. Definir función para rellenar NaN con media fila, asegurando float
def fill_na_with_row_mean(row):
    # Convertir a float para evitar errores
    row = row.astype(float)
    mean = row.mean()
    return row.fillna(mean)

# 4. Aplicar fila a fila la función
numericas_filled = numericas.apply(fill_na_with_row_mean, axis=1)

# 5. Sustituir las columnas numéricas originales por las rellenadas
gasto_capita.loc[:, numericas.columns] = numericas_filled

# 6. Comprobar que no quedan NaN en columnas numéricas
print(gasto_capita[numericas.columns].isna().sum())
# Out:
# na_por_fila    0
# dtype: int64

# %%
gasto_capita = gasto_capita.dropna(axis=0, how='any')

# %%
gasto_capita
# Out:
#                             1988    1989    1990     1991    1992    1993  \
# Country
# Algeria                     43,3    35,0    36,1     22,0    40,1    47,4
# Morocco                     39,4    41,8    44,3     46,7    49,1    49,2
# Tunisia                     29,5    29,0    30,1     31,0    33,7    31,5
# Angola                     137,6   176,4   153,2     87,2    65,0   140,6
# Botswana                    77,0    82,0   121,3    130,2   130,9   132,6
# Burkina Faso                 6,7     7,6     9,3      7,5     7,5     6,2
# Cameroon                    14,7    13,5    16,2     15,5    15,5    13,8
# Ethiopia                    14,2    17,4    16,8     10,9     5,0     3,1
# Ghana                        1,6     1,5     1,8      2,7     2,6     2,5
# Kenya                       12,0    10,5    11,0      8,2     6,5     4,3
# Lesotho                      9,8    12,9    13,5     12,2    13,0    11,7
# ...

# %%
gasto_capita =gasto_capita.drop('na_por_fila', axis=1)

# %%
gasto_capita
# Out:
#                             1988    1989    1990     1991    1992    1993  \
# Country
# Algeria                     43,3    35,0    36,1     22,0    40,1    47,4
# Morocco                     39,4    41,8    44,3     46,7    49,1    49,2
# Tunisia                     29,5    29,0    30,1     31,0    33,7    31,5
# Angola                     137,6   176,4   153,2     87,2    65,0   140,6
# Botswana                    77,0    82,0   121,3    130,2   130,9   132,6
# Burkina Faso                 6,7     7,6     9,3      7,5     7,5     6,2
# Cameroon                    14,7    13,5    16,2     15,5    15,5    13,8
# Ethiopia                    14,2    17,4    16,8     10,9     5,0     3,1
# Ghana                        1,6     1,5     1,8      2,7     2,6     2,5
# Kenya                       12,0    10,5    11,0      8,2     6,5     4,3
# Lesotho                      9,8    12,9    13,5     12,2    13,0    11,7
# ...

# %%
##########  PRIMERA LIMPIEZA HECHA. ASIGNAMOS EL DF A UNA NUEVA VARIABLE PARA EXPORTARLA DESPUÉS

capita = gasto_capita

# %%
########################################################################################333333

capita.to_csv('gasto_capita.csv')
